# %%
# clone darknet repo
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14665, done.
# remote: Total 14665 (delta 0), reused 0 (delta 0), pack-reused 14665
# Receiving objects: 100% (14665/14665), 13.24 MiB | 24.08 MiB/s, done.
# Resolving deltas: 100% (9982/9982), done.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# Out:
# /content/darknet

# %%
# make darknet (builds darknet so that you can then use the darknet executable file to run or train object detectors)
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd darknet
# !cp /content/drive/MyDrive/Vin_DL/train.txt cfg/train.txt
# !cp /content/drive/MyDrive/Vin_DL/test.txt cfg/test.txt
# !mkdir data/train
# !mkdir data/test
# !cp /content/drive/MyDrive/Vin_DL/Data/train.zip data/train
# !cp /content/drive/MyDrive/Vin_DL/Data/test.zip data/test
# !unzip data/train/train.zip -d data
# !unzip data/test/test.zip -d data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/train/1479501517678352569.txt
#   inflating: data/train/1479501523678334289.jpg
#   inflating: data/train/1479501523678334289.txt
#   inflating: data/train/1479501525678834654.jpg
#   inflating: data/train/1479501525678834654.txt
#   inflating: data/train/1479501528669843778.jpg
#   inflating: data/train/1479501528669843778.txt
#   inflating: data/train/1479501532181611726.jpg
#   inflating: data/train/1479501532181611726.txt
#   inflating: data/train/1479501538179273935.jpg
#   inflating: data/train/1479501538179273935.txt
#   inflating: data/train/1479501540680959897.jpg
#   inflating: data/train/1479501540680959897.txt
#   inflating: data/train/1479501541661172071.jpg
#   inflating: data/train/1479501541661172071.txt
#   inflating: data/train/1479501542179970076.jpg
#   inflating: data/train/1479501542179970076.txt
#   inflating: data/train/1479501544182201694.jpg
# ...

# %%
# !cp /content/drive/MyDrive/Vin_DL/YOLOv4_custom/config/yolov4-custom.cfg cfg/yolov4_custom.cfg
# !cp /content/drive/MyDrive/Vin_DL/YOLOv4_custom/config/obj.data cfg/obj.data
# !cp /content/drive/MyDrive/Vin_DL/YOLOv4_custom/config/obj.names cfg/obj.names

# %%
# !cp /content/drive/MyDrive/Vin_DL/YOLOv4_tiny_custom/config/yolov4-tiny-custom.cfg cfg/yolov4_tiny_custom.cfg
# !cp /content/drive/MyDrive/Vin_DL/YOLOv4_tiny_custom/config/obj.data cfg/obj.data
# !cp /content/drive/MyDrive/Vin_DL/YOLOv4_tiny_custom/config/obj.names cfg/obj.names

# %%
# !cp /content/drive/MyDrive/Vin_DL/YOLOv4_original/config/yolov4-original.cfg cfg/yolov4_original.cfg
# !cp /content/drive/MyDrive/Vin_DL/YOLOv4_original/config/obj.data cfg/obj.data
# !cp /content/drive/MyDrive/Vin_DL/YOLOv4_original/config/obj.names cfg/obj.names

# id = {'car': '0', 'motorbike': '1', 'bus': '2', 'truck': '3'}
# def get_box(obj):
#     confidence = str(obj['confidence'])
#     coord = obj['relative_coordinates']
#     x = coord['center_x']
#     y = coord['center_y']
#     w = coord['width']
#     h = coord['height']
#     xmin = str(int((x - w/2) * 1920))
#     xmax = str(int((x + w/2) * 1920))
#     ymin = str(int((y - h/2) * 1080))
#     ymax = str(int((y + h/2) * 1080))
#     c = id[obj['name']]
#     return ' '.join([c, confidence, xmin, ymin, xmax, ymax])

# import json
# !mkdir /content/result_formatted
# result_json = json.load(open('result.json'))
# for result in result_json:
#     path = result['filename'][:-4]
#     path = '/content/result_formatted/' + path.split('/')[-1] + '.txt'
#     objs = result['objects']
#     # objs = filter(lambda x: x['name'] in ('car', 'truck'), objs)
#     obj_list = map(get_box, objs)
#     obj_str = '\n'.join(obj_list)
#     with open(path, 'w') as f:
#         f.write(obj_str)

# %%
# For training yolov4_custom
# !wget yolov4.conv.137 https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137
# For training yolov4_tiny_custom
# !wget yolov4-tiny.conv.29 https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.conv.29
# For training yolov4_original
# !wget yolov4.weights https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights
# Out:
# --2021-01-15 11:43:06--  http://yolov4.conv.137/
# Resolving yolov4.conv.137 (yolov4.conv.137)... failed: Name or service not known.
# wget: unable to resolve host address ‘yolov4.conv.137’
# --2021-01-15 11:43:06--  https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !./darknet detector train cfg/obj.data cfg/yolov4_custom.cfg yolov4.conv.137 -map -dont_show
# !./darknet detector train cfg/obj.data cfg/yolov4_tiny_custom.cfg yolov4-tiny.conv.29 -map -dont_show
# !./darknet detector train cfg/obj.data cfg/yolov4_original.cfg yolov4.weights -map -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.846252), count: 32, class_loss = 6.609908, iou_loss = 133.520676, total_loss = 140.130585
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.855264), count: 11, class_loss = 0.988696, iou_loss = 11.601395, total_loss = 12.590091
#  total_bbox = 160474, rewritten_bbox = 0.692324 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.852573), count: 14, class_loss = 1.647318, iou_loss = 142.430649, total_loss = 144.077972
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.794300), count: 39, class_loss = 5.993936, iou_loss = 129.152969, total_loss = 135.146912
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.829132), count: 13, class_loss = 1.619080, iou_loss = 11.245608, total_loss = 12.864689
# ...

# %%
# !./darknet detector map cfg/obj.data cfg/yolov4_custom.cfg /content/drive/MyDrive/Vin_DL/YOLOv4_custom/backup/yolov4_custom_final.weights
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 32, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
# ...

# %%
# !zip --help
# Out:
# Copyright (c) 1990-2008 Info-ZIP - Type 'zip "-L"' for software license.
# Zip 3.0 (July 5th 2008). Usage:
# zip [-options] [-b path] [-t mmddyyyy] [-n suffixes] [zipfile list] [-xi list]
#   The default action is to add or replace zipfile entries from list, which
#   can include the special name - to compress standard input.
#   If zipfile and list are omitted, zip compresses stdin to stdout.
#   -f   freshen: only changed files  -u   update: only changed or new files
#   -d   delete entries in zipfile    -m   move into zipfile (delete OS files)
#   -r   recurse into directories     -j   junk (don't record) directory names
#   -0   store only                   -l   convert LF to CR LF (-ll CR LF to LF)
#   -1   compress faster              -9   compress better
#   -q   quiet operation              -v   verbose operation/print version info
#   -c   add one-line comments        -z   add zipfile comment
#   -@   read names from stdin        -o   make zipfile as old as latest entry
# ...
